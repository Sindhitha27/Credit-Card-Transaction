# %% [markdown]
# ## <div style="text-align: center; background-color:#bd7e4a;  color: black; padding: 14px; line-height: 0.5;"> <b>Credit Cards Spending : Trends, EDA, Prediction</b></div>

# %% [markdown]
# # <div style="text-align: left; background-color:#d2a56d;  color: black; padding: 14px; line-height: 0.5;"> Importing Libraries</div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# !pip install colorama
import colorama
from colorama import Fore, Back, Style



#ignoring warnings to keep the output clean
import warnings
warnings.filterwarnings('ignore')
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %% [markdown]
# # <div style="text-align: left; background-color: #d2a56d;  color: black; padding: 14px; line-height: 0.5;"> Reading Datasets from csv files</div>

# %%
ccd_df = pd.read_csv('/content/Credit card transactions - India - Simple.csv')
print(Back.YELLOW+ Style.BRIGHT+'Credit Card Spending Habits in India:'+ Style.RESET_ALL)
ccd_df.head().style.set_properties(**{'background-color': '#f1c27d' ,'color':'black','border-color': '#000000'})
# Out:
# Credit Card Spending Habits in India:
# <style type="text/css">
# #T_210e2_row0_col0, #T_210e2_row0_col1, #T_210e2_row0_col2, #T_210e2_row0_col3, #T_210e2_row0_col4, #T_210e2_row0_col5, #T_210e2_row0_col6, #T_210e2_row1_col0, #T_210e2_row1_col1, #T_210e2_row1_col2, #T_210e2_row1_col3, #T_210e2_row1_col4, #T_210e2_row1_col5, #T_210e2_row1_col6, #T_210e2_row2_col0, #T_210e2_row2_col1, #T_210e2_row2_col2, #T_210e2_row2_col3, #T_210e2_row2_col4, #T_210e2_row2_col5, #T_210e2_row2_col6, #T_210e2_row3_col0, #T_210e2_row3_col1, #T_210e2_row3_col2, #T_210e2_row3_col3, #T_210e2_row3_col4, #T_210e2_row3_col5, #T_210e2_row3_col6, #T_210e2_row4_col0, #T_210e2_row4_col1, #T_210e2_row4_col2, #T_210e2_row4_col3, #T_210e2_row4_col4, #T_210e2_row4_col5, #T_210e2_row4_col6 {
#   background-color: #f1c27d;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_210e2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_210e2_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_210e2_level0_col1" class="col_heading level0 col1" >City</th>
#       <th id="T_210e2_level0_col2" class="col_heading level0 col2" >Date</th>
#       <th id="T_210e2_level0_col3" class="col_heading level0 col3" >Card Type</th>
#       <th id="T_210e2_level0_col4" class="col_heading level0 col4" >Exp Type</th>
#       <th id="T_210e2_level0_col5" class="col_heading level0 col5" >Gender</th>
#       <th id="T_210e2_level0_col6" class="col_heading level0 col6" >Amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_210e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_210e2_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_210e2_row0_col1" class="data row0 col1" >Delhi, India</td>
#       <td id="T_210e2_row0_col2" class="data row0 col2" >29-Oct-14</td>
#       <td id="T_210e2_row0_col3" class="data row0 col3" >Gold</td>
#       <td id="T_210e2_row0_col4" class="data row0 col4" >Bills</td>
#       <td id="T_210e2_row0_col5" class="data row0 col5" >F</td>
#       <td id="T_210e2_row0_col6" class="data row0 col6" >82475</td>
#     </tr>
#     <tr>
#       <th id="T_210e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_210e2_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_210e2_row1_col1" class="data row1 col1" >Greater Mumbai, India</td>
#       <td id="T_210e2_row1_col2" class="data row1 col2" >22-Aug-14</td>
#       <td id="T_210e2_row1_col3" class="data row1 col3" >Platinum</td>
#       <td id="T_210e2_row1_col4" class="data row1 col4" >Bills</td>
#       <td id="T_210e2_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_210e2_row1_col6" class="data row1 col6" >32555</td>
#     </tr>
#     <tr>
#       <th id="T_210e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_210e2_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_210e2_row2_col1" class="data row2 col1" >Bengaluru, India</td>
#       <td id="T_210e2_row2_col2" class="data row2 col2" >27-Aug-14</td>
#       <td id="T_210e2_row2_col3" class="data row2 col3" >Silver</td>
#       <td id="T_210e2_row2_col4" class="data row2 col4" >Bills</td>
#       <td id="T_210e2_row2_col5" class="data row2 col5" >F</td>
#       <td id="T_210e2_row2_col6" class="data row2 col6" >101738</td>
#     </tr>
#     <tr>
#       <th id="T_210e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_210e2_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_210e2_row3_col1" class="data row3 col1" >Greater Mumbai, India</td>
#       <td id="T_210e2_row3_col2" class="data row3 col2" >12-Apr-14</td>
#       <td id="T_210e2_row3_col3" class="data row3 col3" >Signature</td>
#       <td id="T_210e2_row3_col4" class="data row3 col4" >Bills</td>
#       <td id="T_210e2_row3_col5" class="data row3 col5" >F</td>
#       <td id="T_210e2_row3_col6" class="data row3 col6" >123424</td>
#     </tr>
#     <tr>
#       <th id="T_210e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_210e2_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_210e2_row4_col1" class="data row4 col1" >Bengaluru, India</td>
#       <td id="T_210e2_row4_col2" class="data row4 col2" >5-May-15</td>
#       <td id="T_210e2_row4_col3" class="data row4 col3" >Gold</td>
#       <td id="T_210e2_row4_col4" class="data row4 col4" >Bills</td>
#       <td id="T_210e2_row4_col5" class="data row4 col5" >F</td>
#       <td id="T_210e2_row4_col6" class="data row4 col6" >171574</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <div style="text-align: left; background-color: #d2a56d;  color: black; padding: 14px; line-height: 0.5;"> Data Preparation</div>

# %%
print(Back.YELLOW+ Style.BRIGHT+'Count of Null values:'+ Style.RESET_ALL)
na_df=ccd_df.isnull().sum().reset_index()
na_df.style.set_properties(**{'background-color': '#f1c27d' ,'color':'black','border-color': '#000000'})
# Out:
# Count of Null values:
# <style type="text/css">
# #T_e9d3b_row0_col0, #T_e9d3b_row0_col1, #T_e9d3b_row1_col0, #T_e9d3b_row1_col1, #T_e9d3b_row2_col0, #T_e9d3b_row2_col1, #T_e9d3b_row3_col0, #T_e9d3b_row3_col1, #T_e9d3b_row4_col0, #T_e9d3b_row4_col1, #T_e9d3b_row5_col0, #T_e9d3b_row5_col1, #T_e9d3b_row6_col0, #T_e9d3b_row6_col1 {
#   background-color: #f1c27d;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_e9d3b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9d3b_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_e9d3b_level0_col1" class="col_heading level0 col1" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9d3b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9d3b_row0_col0" class="data row0 col0" >index</td>
#       <td id="T_e9d3b_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9d3b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9d3b_row1_col0" class="data row1 col0" >City</td>
#       <td id="T_e9d3b_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9d3b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9d3b_row2_col0" class="data row2 col0" >Date</td>
#       <td id="T_e9d3b_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9d3b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9d3b_row3_col0" class="data row3 col0" >Card Type</td>
#       <td id="T_e9d3b_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9d3b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e9d3b_row4_col0" class="data row4 col0" >Exp Type</td>
#       <td id="T_e9d3b_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9d3b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e9d3b_row5_col0" class="data row5 col0" >Gender</td>
#       <td id="T_e9d3b_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e9d3b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e9d3b_row6_col0" class="data row6 col0" >Amount</td>
#       <td id="T_e9d3b_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.0;"> <b>Observation:</b>
#     There are no null values in any of the features in the dataset

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observations:</b>
#
#    In the dataset there are 6 columns and 26052 rows:
#    <b>Numerical columns:</b> Amount
#    <b>Categorical columns:</b> City, Date, Card Type, Exp Type, Gender

# %%
print(Back.YELLOW+ Style.BRIGHT+ 'Summary of Credit Card Data:' + Style.RESET_ALL)
print('Total number of ' + Fore.BLACK+ Style.BRIGHT+ 'Card Type' + Style.RESET_ALL+'       :',\
      Fore.RED+ Style.BRIGHT+ str(len(ccd_df['Card Type'].unique())) + Style.RESET_ALL + ' (Gold, Platinum, Silver, Signature)')

print('Total number of ' + Fore.BLACK+ Style.BRIGHT+ 'Expenses Type' + Style.RESET_ALL +'   :',\
      Fore.RED+ Style.BRIGHT+ str(len(ccd_df['Exp Type'].unique())) + Style.RESET_ALL + ' (Bills, Food, Entertainment, Grocery, Fuel, Travel)')

print('Total number of ' + Fore.BLACK+ Style.BRIGHT+ 'Cities' + Style.RESET_ALL +'          :',\
      Fore.RED+ Style.BRIGHT+ str(len(ccd_df['Gender'].unique())) + Style.RESET_ALL + ' (Male, Female)')

print('Total number of ' + Fore.BLACK+ Style.BRIGHT+ 'Cities' + Style.RESET_ALL +'          :',\
      Fore.RED+ Style.BRIGHT+ str(len(ccd_df['City'].unique())) + Style.RESET_ALL)
# Out:
# Summary of Credit Card Data:
# Total number of Card Type       : 4 (Gold, Platinum, Silver, Signature)
# Total number of Expenses Type   : 6 (Bills, Food, Entertainment, Grocery, Fuel, Travel)
# Total number of Cities          : 2 (Male, Female)
# Total number of Cities          : 986

# %% [markdown]
# # <div style="text-align: left; background-color: #d2a56d;  color: black; padding: 14px; line-height: 0.5;"> Exploratory Data Analysis</div>

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Monthly Expenditure Trend Analysis</div>

# %%
ccd_df['Date'] = pd.to_datetime(ccd_df['Date'])
ccd_df['Year-Month'] = ccd_df['Date'].to_numpy().astype('datetime64[M]')
ccd_df['City'] = ccd_df['City'].apply(lambda x: x.split(",")[0])

monthly_df = ccd_df[['Year-Month','Card Type','Amount']].groupby(['Year-Month','Card Type']).agg(mean_exp_amt=('Amount', 'mean')).reset_index().sort_values(['Year-Month','Card Type'])
monthly_df['mean_exp_amt']=monthly_df['mean_exp_amt'].astype('int')

fig = px.line(data_frame=monthly_df, x='Year-Month',y='mean_exp_amt', color='Card Type',template='simple_white',markers=True)
# fig.update_traces(mode="markers+lines", hovertemplate=None)
fig.update_yaxes(showgrid=True)
fig.update_layout(hovermode="x unified")

fig.update_layout(
    title='<b>Monthly Mean Expenditure Trend - Line Plot</b>',
    font_family="Courier New",
    title_font_family="Courier New",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Year Month</b>",
    yaxis_title="<b>Mean Expenditure</b>",
    legend_title='<b>Card Type</b>',
    legend_title_font_color="red",
    plot_bgcolor = '#FFFFFF'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a4c03d04-c6c9-4e5e-90f0-e7c04fcaee61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4c03d04-c6c9-4e5e-90f0-e7c04fcaee61")) {                    Plotly.newPlot(                        "a4c03d04-c6c9-4e5e-90f0-e7c04fcaee61",                        [{"hovertemplate":"Card Type=Gold\u003cbr\u003eYear-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gold","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Gold","orientation":"v","showlegend":true,"x":["2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00"],"xaxis":"x","y":[161768,149863,149463,152343,152273,150255,160182,159507,162513,150542,154888,152744,154024,153007,151978,158443,152387,159867,158070,148372],"yaxis":"y","type":"scatter"},{"hovertemplate":"Card Type=Platinum\u003cbr\u003eYear-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Platinum","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Platinum","orientation":"v","showlegend":true,"x":["2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00"],"xaxis":"x","y":[162290,159395,160281,161571,159866,156358,158150,148723,155870,146422,160488,160569,148649,161751,150206,168659,147718,161261,166475,152911],"yaxis":"y","type":"scatter"},{"hovertemplate":"Card Type=Signature\u003cbr\u003eYear-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Signature","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Signature","orientation":"v","showlegend":true,"x":["2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00"],"xaxis":"x","y":[167242,154364,162879,152292,159413,156081,165108,157525,145689,153540,154201,157343,155993,159375,153498,156601,162828,146676,162841,157661],"yaxis":"y","type":"scatter"},{"hovertemplate":"Card Type=Silver\u003cbr\u003eYear-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Silver","line":{"color":"#D62728","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Silver","orientation":"v","showlegend":true,"x":["2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00 ...

# %%
monthly_df['Year-Month']=monthly_df['Year-Month'].astype(str)
fig=px.violin(data_frame=monthly_df, x='Year-Month',y='mean_exp_amt',template='simple_white',
              color='Year-Month',
               color_discrete_sequence= ['red', 'orange', 'blue', 'green'])
fig.update_yaxes(showgrid=True)

fig.update_layout(
    title='<b>Monthly Mean Expenditure Trend-Violin Plot</b>',
    font_family="Courier New",
    title_font_family="Times New Roman",title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Year Month</b>",
    yaxis_title="<b>Mean Expenditure</b>",
    plot_bgcolor = '#FFFFFF'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9946c094-f55a-48d7-b230-da8c6c1f287d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9946c094-f55a-48d7-b230-da8c6c1f287d")) {                    Plotly.newPlot(                        "9946c094-f55a-48d7-b230-da8c6c1f287d",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Year-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2013-10-01","marker":{"color":"red"},"name":"2013-10-01","offsetgroup":"2013-10-01","orientation":"v","scalegroup":"True","showlegend":true,"x":["2013-10-01","2013-10-01","2013-10-01","2013-10-01"],"x0":" ","xaxis":"x","y":[161768,162290,167242,151391],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Year-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2013-11-01","marker":{"color":"orange"},"name":"2013-11-01","offsetgroup":"2013-11-01","orientation":"v","scalegroup":"True","showlegend":true,"x":["2013-11-01","2013-11-01","2013-11-01","2013-11-01"],"x0":" ","xaxis":"x","y":[149863,159395,154364,147037],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Year-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2013-12-01","marker":{"color":"blue"},"name":"2013-12-01","offsetgroup":"2013-12-01","orientation":"v","scalegroup":"True","showlegend":true,"x":["2013-12-01","2013-12-01","2013-12-01","2013-12-01"],"x0":" ","xaxis":"x","y":[149463,160281,162879,148921],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Year-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2014-01-01","marker":{"color":"green"},"name":"2014-01-01","offsetgroup":"2014-01-01","orientation":"v","scalegroup":"True","showlegend":true,"x":["2014-01-01","2014-01-01","2014-01-01","2014-01-01"],"x0":" ","xaxis":"x","y":[152343,161571,152292,151256],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Year-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2014-02-01","marker":{"color":"red"},"name":"2014-02-01","offsetgroup":"2014-02-01","orientation":"v","scalegroup":"True","showlegend":true,"x":["2014-02-01","2014-02-01","2014-02-01","2014-02-01"],"x0":" ","xaxis":"x","y":[152273,159866,159413,163426],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Year-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2014-03-01","marker":{"color":"orange"},"name":"2014-03-01","offsetgroup":"2014-03-01","orientation":"v","scalegroup":"True","showlegend":true,"x":["2014-03-01","2014-03-01","2014-03-01","2014-03-01"],"x0":" ","xaxis":"x","y":[150255,156358,156081,156012],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Year-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2014-04-01","marker":{"color":"blue"},"name":"2014-04-01","offsetgroup":"2014-04-01","orientation":"v","scalegroup":"True","showlegend":true,"x":["2014-04-01","2014-04-01","2014-04-01","2014-04-01"],"x0":" ","xaxis":"x","y":[160182,158150,165108,160067],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Year-Month=%{x}\u003cbr\u003emean_exp_amt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2014-05-01","marker":{"color":"green" ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observation:</b>
#      In the above plots, no clear pattern of expenses emerges over time for any of the card types. The amounts for all card types fluctuate between 135K and 180K.

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Spend Analysis on Card Type</div>

# %%
ccd_cnt_amt_df = ccd_df[['Card Type', 'Amount']].groupby('Card Type')['Amount'].agg(['sum','count']).reset_index()
colors = ['#83502e', '#bd7e4a', '#d2a56d', '#f1c27d', '#ffdbac', '#ffeead']
colors2=['red', 'orange', 'blue', 'green', 'brown', 'yellow']

fig = make_subplots(rows=1,cols=2,specs=[[{'type':'domain'},{'type':'xy'}]],
                    vertical_spacing = 0.25, horizontal_spacing=.1,
                    subplot_titles=["Count","Amount"])
fig.add_trace(go.Pie(labels=ccd_cnt_amt_df['Card Type'], values=ccd_cnt_amt_df['count'],name='count', marker_colors=colors),row=1,col=1)

fig.add_trace(go.Bar(x=ccd_cnt_amt_df['Card Type'],y=ccd_cnt_amt_df['sum'], text=ccd_cnt_amt_df['sum'], marker_color=colors ),row=1,col=2)

fig.update_layout(height=400,width=1000,
                  title_text="<b>Card Type wise Count and Amount</b>",
                  title_xanchor="center",
                  title_x=0.5,
                  title_font_family="Times New Roman",title_font_color="#83502e",
                  title_font_size=20,
                  showlegend=True,
                  legend_bgcolor='#fdf1cb',
                  paper_bgcolor='#fdf1cb',
                  plot_bgcolor = '#fdf1cb')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4fc3efe2-81f7-4357-a20d-b67902e070e0" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fc3efe2-81f7-4357-a20d-b67902e070e0")) {                    Plotly.newPlot(                        "4fc3efe2-81f7-4357-a20d-b67902e070e0",                        [{"labels":["Gold","Platinum","Signature","Silver"],"marker":{"colors":["#83502e","#bd7e4a","#d2a56d","#f1c27d","#ffdbac","#ffeead"]},"name":"count","values":[6367,6398,6447,6840],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]}},{"marker":{"color":["#83502e","#bd7e4a","#d2a56d","#f1c27d","#ffdbac","#ffeead"]},"text":[984539536.0,1007639019.0,1013041105.0,1069613713.0],"x":["Gold","Platinum","Signature","Silver"],"y":[984539536,1007639019,1013041105,1069613713],"type":"bar","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode" ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.0;"> <b>Observation:</b>
#     The count of transactions and the total sum of transaction amounts are nearly the same across all card types, with a slightly higher value observed for Silver.

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Expense Type Spend Analysis</div>

# %%
#Expense Type : Amount and Count
ccd_exp_amt_df = ccd_df[['Exp Type', 'Amount']].groupby('Exp Type')['Amount'].agg(['sum','count']).reset_index()
ccd_exp_amt_df.columns=['Exp Type', 'Total Amount', 'Transactions']
ccd_exp_amt_df = ccd_exp_amt_df.sort_values('Total Amount', ascending= False)
ccd_exp_amt_df

fig = make_subplots(rows=1,cols=2,specs=[[{'type':'domain'},{'type':'xy'}]],
                    vertical_spacing = 0.25, horizontal_spacing=.1,
                    subplot_titles=["Count","Amount"]    )
fig.add_trace(go.Pie(labels=ccd_exp_amt_df['Exp Type'], values=ccd_exp_amt_df['Transactions'], marker_colors=colors),row=1,col=1)

fig.add_trace(go.Bar(x=ccd_exp_amt_df['Exp Type'], y=ccd_exp_amt_df['Total Amount'], text=ccd_exp_amt_df['Total Amount'], marker_color=colors),row=1,col=2)

fig.update_layout(height=400,width=1000, title_text="<b>Expense Type wise Count and Total Amount</b>",
                  title_font_family="Times New Roman",title_font_color="#83502e",
                  title_font_size=20,
                  title_xanchor="center",
                  title_x=0.5,
                  showlegend=True,
                  legend_bgcolor='#fdf1cb',
                  paper_bgcolor='#fdf1cb',
                  plot_bgcolor ='#fdf1cb')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="196537fb-5b9f-4043-91db-0ea7774de18e" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("196537fb-5b9f-4043-91db-0ea7774de18e")) {                    Plotly.newPlot(                        "196537fb-5b9f-4043-91db-0ea7774de18e",                        [{"labels":["Bills","Food","Fuel","Entertainment","Grocery","Travel"],"marker":{"colors":["#83502e","#bd7e4a","#d2a56d","#f1c27d","#ffdbac","#ffeead"]},"values":[5078,5463,5257,4762,4754,738],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]}},{"marker":{"color":["#83502e","#bd7e4a","#d2a56d","#f1c27d","#ffdbac","#ffeead"]},"text":[907072473.0,824724009.0,789135821.0,726437536.0,718207923.0,109255611.0],"x":["Bills","Food","Fuel","Entertainment","Grocery","Travel"],"y":[907072473,824724009,789135821,726437536,718207923,109255611],"type":"bar","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"m ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.0;"> <b>Observation:</b>
#     We can see more number of transactons in <b>Food</b> followed by <b>Fuel</b> and <b>Bills</b> in the third place.
#     Total Amount wise we have highest amount in <b>Bills</b>, followed by <b>Food</b> and <b>Fuel</b> in the third place

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Spend Analysis on Gender</div>

# %%
#Expense Type : Amount and Count
gen_exp_amt_df = ccd_df[['Gender', 'Amount']].groupby('Gender')['Amount'].agg(['sum','count']).reset_index()
gen_exp_amt_df.columns=['Gender', 'Total Amount', 'Transactions']
gen_exp_amt_df = gen_exp_amt_df.sort_values('Total Amount', ascending= False)
gen_exp_amt_df

fig = make_subplots(rows=1,cols=2,specs=[[{'type':'domain'},{'type':'xy'}]],
                    vertical_spacing = 0.25, horizontal_spacing=.1,
                    subplot_titles=["Count","Amount"]    )
fig.add_trace(go.Pie(labels=gen_exp_amt_df['Gender'], values=gen_exp_amt_df['Transactions'], name="Count", marker_colors=colors),row=1,col=1)
fig.add_trace(go.Bar(x=gen_exp_amt_df['Gender'], y=gen_exp_amt_df['Total Amount'],name="Total Amount", text=gen_exp_amt_df['Total Amount'],marker_color=colors),row=1,col=2)
fig.update_layout(height=400,width=1000, title_text="<b>Gender wise Count and Total Amount</b>",
                  title_font_family="Times New Roman",title_font_color="#83502e",
                  title_xanchor="center",
                  title_x=0.5,
                  title_font_size=20,
                  showlegend=True,
                  legend_bgcolor='#fdf1cb',
                  paper_bgcolor='#fdf1cb',
                  plot_bgcolor ='#fdf1cb')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="13636dfd-27ed-4d42-a461-1a9a41dd18e4" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13636dfd-27ed-4d42-a461-1a9a41dd18e4")) {                    Plotly.newPlot(                        "13636dfd-27ed-4d42-a461-1a9a41dd18e4",                        [{"labels":["F","M"],"marker":{"colors":["#83502e","#bd7e4a","#d2a56d","#f1c27d","#ffdbac","#ffeead"]},"name":"Count","values":[13680,12372],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]}},{"marker":{"color":["#83502e","#bd7e4a","#d2a56d","#f1c27d","#ffdbac","#ffeead"]},"name":"Total Amount","text":[2205311030.0,1869522343.0],"x":["F","M"],"y":[2205311030,1869522343],"type":"bar","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marke ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observation: </b>
# We can see females spending more amount than males.

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Classifying Cities into Tier-1,  Tier-2 and  Tier-3</div>

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.0;"> <b>Observation:</b>The spending paterns are generally affected by the city/town in which the customer lives. So, let us classify the cities given in the dataset into Tier-1, Tier-2 and Tier-3 cities.
#
# Reference : Clasification of the cities taken from the source: https://en.wikipedia.org/wiki/Classification_of_Indian_cities

# %% [markdown]
# ![City_Tiers.PNG](attachment:d0b625c3-80ac-4e49-a2bd-0c72fe58fef7.PNG)

# %%
t1=['Ahmedabad', 'Bengaluru', 'Chennai', 'Delhi', 'Hyderabad', 'Kolkata', 'Mumbai', 'Pune']
t2=['Ajmer','Aligarh','Amravati','Amritsar','Anand','Asansol','Aurangabad','Bareilly','Belagavi','Bhavnagar','Bhiwandi','Bhopal','Bhubaneswar','Bikaner','Bilaspur','Bokaro Steel City','Burdwan','Chandigarh','Coimbatore','Cuttack','Dahod','Dehradun','Dombivli','Dhanbad','Bhilai','Durgapur','Erode','Faridabad','Ghaziabad','Gorakhpur','Guntur','Gurugram','Guwahati','Gwalior','Hamirpur','Hubli-Dharwad','Indore','Jabalpur','Jaipur','Jalandhar','Jalgaon','Jammu','Jamnagar','Jamshedpur','Jhansi','Jodhpur','Kalaburagi','Kakinada','Kannur','Kanpur','Karnal','Kochi','Kolhapur','Kollam','Kozhikode','Kurnool','Ludhiana','Lucknow','Madurai','Malappuram','Mathura','Mangaluru','Meerut','Moradabad','Mysore','Nagpur','Nanded-Waghala','Nashik','Nellore','Noida','Patna','Puducherry','Purulia','Prayagraj','Raipur','Rajkot','Rajahmundry','Ranchi','Rourkela','Ratlam','Salem','Sangli','Shimla','Siliguri','Solapur','Srinagar','Surat','Thanjavur','Thiruvananthapuram','Thrissur','Tiruchirappalli','Tirunelveli','Tiruvannamalai','Ujjain','Vijayapura','Vadodara','Varanasi','Vasai-Virar','Vijayawada','Visakhapatnam','Vellore','Warangal']

def city_tier(city):
  if city in t1:
    return 'Tier-1'
  elif city in t2:
    return 'Tier-2'
  else :
    return 'Tier-3'

ccd_df['City'] = ccd_df['City'].apply(lambda x: x.split(',')[0])
ccd_df['City Tier'] = ccd_df['City'].apply(lambda x: city_tier(x))
ccd_df.head().style.set_properties(**{'background-color': '#f1c27d' ,'color':'black','border-color': '#000000'})
# Out:
# <style type="text/css">
# #T_fed59_row0_col0, #T_fed59_row0_col1, #T_fed59_row0_col2, #T_fed59_row0_col3, #T_fed59_row0_col4, #T_fed59_row0_col5, #T_fed59_row0_col6, #T_fed59_row0_col7, #T_fed59_row0_col8, #T_fed59_row1_col0, #T_fed59_row1_col1, #T_fed59_row1_col2, #T_fed59_row1_col3, #T_fed59_row1_col4, #T_fed59_row1_col5, #T_fed59_row1_col6, #T_fed59_row1_col7, #T_fed59_row1_col8, #T_fed59_row2_col0, #T_fed59_row2_col1, #T_fed59_row2_col2, #T_fed59_row2_col3, #T_fed59_row2_col4, #T_fed59_row2_col5, #T_fed59_row2_col6, #T_fed59_row2_col7, #T_fed59_row2_col8, #T_fed59_row3_col0, #T_fed59_row3_col1, #T_fed59_row3_col2, #T_fed59_row3_col3, #T_fed59_row3_col4, #T_fed59_row3_col5, #T_fed59_row3_col6, #T_fed59_row3_col7, #T_fed59_row3_col8, #T_fed59_row4_col0, #T_fed59_row4_col1, #T_fed59_row4_col2, #T_fed59_row4_col3, #T_fed59_row4_col4, #T_fed59_row4_col5, #T_fed59_row4_col6, #T_fed59_row4_col7, #T_fed59_row4_col8 {
#   background-color: #f1c27d;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_fed59" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fed59_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_fed59_level0_col1" class="col_heading level0 col1" >City</th>
#       <th id="T_fed59_level0_col2" class="col_heading level0 col2" >Date</th>
#       <th id="T_fed59_level0_col3" class="col_heading level0 col3" >Card Type</th>
#       <th id="T_fed59_level0_col4" class="col_heading level0 col4" >Exp Type</th>
#       <th id="T_fed59_level0_col5" class="col_heading level0 col5" >Gender</th>
#       <th id="T_fed59_level0_col6" class="col_heading level0 col6" >Amount</th>
#       <th id="T_fed59_level0_col7" class="col_heading level0 col7" >Year-Month</th>
#       <th id="T_fed59_level0_col8" class="col_heading level0 col8" >City Tier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fed59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fed59_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_fed59_row0_col1" class="data row0 col1" >Delhi</td>
#       <td id="T_fed59_row0_col2" class="data row0 col2" >2014-10-29 00:00:00</td>
#       <td id="T_fed59_row0_col3" class="data row0 col3" >Gold</td>
#       <td id="T_fed59_row0_col4" class="data row0 col4" >Bills</td>
#       <td id="T_fed59_row0_col5" class="data row0 col5" >F</td>
#       <td id="T_fed59_row0_col6" class="data row0 col6" >82475</td>
#       <td id="T_fed59_row0_col7" class="data row0 col7" >2014-10-01 00:00:00</td>
#       <td id="T_fed59_row0_col8" class="data row0 col8" >Tier-1</td>
#     </tr>
#     <tr>
#       <th id="T_fed59_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fed59_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_fed59_row1_col1" class="data row1 col1" >Greater Mumbai</td>
#       <td id="T_fed59_row1_col2" class="data row1 col2" >2014-08-22 00:00:00</td>
#       <td id="T_fed59_row1_col3" class="data row1 col3" >Platinum</td>
#       <td id="T_fed59_row1_col4" class="data row1 col4" >Bills</td>
#       <td id="T_fed59_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_fed59_row1_col6" class="data row1 col6" >32555</td>
#       <td id="T_fed59_row1_col7" class="data row1 col7" >2014-08-01 00:00:00</td>
#       <td id="T_fed59_row1_col8" class="data row1 col8" >Tier-3</td>
#     </tr>
#     <tr>
#       <th id="T_fed59_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fed59_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_fed59_row2_col1" class="data row2 col1" >Bengaluru</td>
#       <td id="T_fed59_row2_col2" class="data row2 col2" >2014-08-27 00:00:00</td>
#       <td id="T_fed59_row2_col3" class="data row2 col3" >Silver</td>
#       <td id="T_fed59_row2_col4" class="data row2 col4" >Bills</td>
#       <td id="T_fed59_row2_col5" class="data row2 col5" >F</td>
#       <td id="T_fed59_row2_col6" class="data row2 col6" >101738</td>
#       <td id="T_fed59_row2_col7" class="data row2 col7" >2014-08-01 00:00:00</td>
#       <td id="T_fed59_row2_col8" class="data row2 col8" >Tier-1</td>
#     </tr>
#     <tr>
#       <th id="T_fed59_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fed59_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_fed59_row3_col1" class="data row3 col1" >Greater Mumbai</td>
#       <td id="T_fed59_row3_col2" class="data row3 col2" >2014-04-12 00:00:00</td>
#       <td id="T_fed59_row3_col3" class="data row3 col3" >Signature</td>
#       <td id="T_fed59_row3_col4" class="data row3 col4" >Bills</td>
#       <td id="T_fed59_row3_col5" class="data row3 col5" >F</td>
#       <td id="T_fed59_row3_col6" class="data row3 col6" >123424</td>
#       <td id="T_fed59_row3_col7" class="data row3 col7" >2014-04-01 00:00:00</td>
#       <td id="T_fed59_row3_col8" class="data row3 col8" >Tier-3</td>
#     </tr>
#     <tr>
#       <th id="T_fed59_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fed59_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_fed59_row4_col1" class="data row4 col1" >Bengaluru</td>
#       <td id="T_fed59_row4_col2" class="data row4 col2" >2015-05-05 00:00:00</td>
#       <td id="T_fed59_row4_col3" class="data row4 col3" >Gold</td>
#       <td id="T_fed59_row4_col4" class="data row4 col4" >Bills</td>
#       <td id="T_fed59_row4_col5" class="data row4 col5" >F</td>
#       <td id="T_fed59_row4_col6" class="data row4 col6" >171574</td>
#       <td id="T_fed59_row4_col7" class="data row4 col7" >2015-05-01 00:00:00</td>
#       <td id="T_fed59_row4_col8" class="data row4 col8" >Tier-1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> City Tier-wise Analysis on Spent Amount</div>

# %%
tier_df2=ccd_df[['City Tier', 'Amount']].groupby('City Tier').agg(Total_Amount=('Amount', 'sum')).reset_index()

fig = px.bar(tier_df2,
             x='City Tier', y='Total_Amount', color='City Tier', color_discrete_sequence=colors, text_auto='True' )

fig.update_layout(height=400,width=1000, title_text="<b>City Tier-wise Amount Spent</b>",
                  title_font_family="Times New Roman",title_font_color="#83502e",
                  title_xanchor="center",
                  title_x=0.5,
                  title_font_size=20,
                  xaxis_title="<b>City Tier</b>",
                  yaxis_title="<b>Amount Spent</b>",
                  legend_title='<b>City Tier</b>',
                  legend_title_font_color="#83502e",
                  showlegend=True,
                  plot_bgcolor ='#fdf1cb')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="13e95f88-46f4-423b-94c0-7ebfb95d6aa4" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13e95f88-46f4-423b-94c0-7ebfb95d6aa4")) {                    Plotly.newPlot(                        "13e95f88-46f4-423b-94c0-7ebfb95d6aa4",                        [{"alignmentgroup":"True","hovertemplate":"City Tier=%{x}\u003cbr\u003eTotal_Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-1","marker":{"color":"#83502e","pattern":{"shape":""}},"name":"Tier-1","offsetgroup":"Tier-1","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1"],"xaxis":"x","y":[2151055211],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City Tier=%{x}\u003cbr\u003eTotal_Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-2","marker":{"color":"#bd7e4a","pattern":{"shape":""}},"name":"Tier-2","offsetgroup":"Tier-2","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-2"],"xaxis":"x","y":[533206525],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City Tier=%{x}\u003cbr\u003eTotal_Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-3","marker":{"color":"#d2a56d","pattern":{"shape":""}},"name":"Tier-3","offsetgroup":"Tier-3","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-3"],"xaxis":"x","y":[1390571637],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> City Tier-wise Analysis on Credit Card Transactions Count</div>

# %%
tier_df=ccd_df[['City Tier']].groupby('City Tier').size().reset_index()
tier_df.columns=['City Tier','Count']

fig = px.bar(tier_df,
             x='City Tier', y='Count', color='City Tier', color_discrete_sequence=colors, text_auto='True' )

fig.update_layout(height=400,width=1000, title_text="<b>City Tier-wise Transaction Count</b>",
                  title_font_family="Times New Roman",title_font_color="#83502e",
                  title_xanchor="center",
                  title_x=0.5,
                  title_font_size=20,
                  xaxis_title="<b>City Tier</b>",
                  yaxis_title="<b>Transaction Count</b>",
                  legend_title='<b>City Tier</b>',
                  legend_title_font_color="#83502e",
                  showlegend=True,
                  plot_bgcolor ='#fdf1cb')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="814fb906-d42c-45c2-97e7-cdcb186cd1c8" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("814fb906-d42c-45c2-97e7-cdcb186cd1c8")) {                    Plotly.newPlot(                        "814fb906-d42c-45c2-97e7-cdcb186cd1c8",                        [{"alignmentgroup":"True","hovertemplate":"City Tier=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-1","marker":{"color":"#83502e","pattern":{"shape":""}},"name":"Tier-1","offsetgroup":"Tier-1","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1"],"xaxis":"x","y":[13603],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City Tier=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-2","marker":{"color":"#bd7e4a","pattern":{"shape":""}},"name":"Tier-2","offsetgroup":"Tier-2","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-2"],"xaxis":"x","y":[3533],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City Tier=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-3","marker":{"color":"#d2a56d","pattern":{"shape":""}},"name":"Tier-3","offsetgroup":"Tier-3","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-3"],"xaxis":"x","y":[8916],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...

# %%
city_cnt_df = ccd_df[['City Tier']].groupby(['City Tier']).size().reset_index()
city_cnt_df.columns = ['City Tier','Count']

fig = px.pie(city_cnt_df,
            names = 'City Tier' , values = 'Count' , color = 'City Tier' , hole = 0.25 ,
            template = 'ggplot2' , title = '<b> City Tier-wise Credit Card Transaction Percentage </b>',
            labels={"Tier-1":"<b>Tier-1</b>"}, color_discrete_sequence=colors)

fig.update_traces(textinfo='percent+ value + label')

fig.update_layout(legend=dict(
     orientation="h",
    yanchor="bottom",
    y=-0.1,
    xanchor="center",
    x=0.5
    ))


fig.update_layout(
    title_font_family="Times New Roman",
    title_font_color="#83502e",
    title_font_size=20,
    title_xanchor="center",
    title_x=0.5
)

fig.update_traces(textposition='inside', textinfo='percent+label',
                         pull=[0, 0.2, 0], rotation=0)



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b9994d60-fa26-44cc-8a8b-6609ea840161" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9994d60-fa26-44cc-8a8b-6609ea840161")) {                    Plotly.newPlot(                        "b9994d60-fa26-44cc-8a8b-6609ea840161",                        [{"customdata":[["Tier-1"],["Tier-2"],["Tier-3"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.25,"hovertemplate":"City Tier=%{customdata[0]}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Tier-1","Tier-2","Tier-3"],"legendgroup":"","marker":{"colors":["#83502e","#bd7e4a","#d2a56d"]},"name":"","showlegend":true,"values":[13603,3533,8916],"type":"pie","textinfo":"percent+label","pull":[0,0.2,0],"rotation":0,"textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"scattergl"}],"scattermapbox": ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observations: </b>The number cities listed under Tier-1 are only <b>7</b>, but they comprises of <b>13603</b> transactions to become highest among all the three tiers. This could be due to life style habits and digitisation of business in the Tier-1 cities.
#
# In the Tier-2 group, we observe fewer transactions compared to the Tier-3 group, likely due to the larger number of cities included in the Tier-3 category.
#
# So, it is worth analysing the number of transactions per city in each tier.

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Analysis of Transactions Per City</div>

# %%
city_cnt_df = ccd_df[['City Tier']].groupby(['City Tier']).size().reset_index()
city_cnt_df.columns = ['City Tier','Count']
city_cnt_df['Num_of_Cities'] = [7, 85, 894]  #Number of cities as per city clasification
city_cnt_df['Trans_Per_City'] = city_cnt_df['Count'] /city_cnt_df['Num_of_Cities']
city_cnt_df['Trans_Per_City']=city_cnt_df['Trans_Per_City'].astype('int')

fig =px.bar(city_cnt_df, y='City Tier',x='Trans_Per_City', orientation='h', color='City Tier', color_discrete_sequence=colors,text_auto='True')
fig.update_layout(
    title='<b>Number of Transactions per City</b>',
    font_family="Times New Roman",
    title_font_family="Times New Roman",title_font_color="#83502e",
    title_font_size=20,
    xaxis_title="<b>No. of Transactions</b>",
    yaxis_title="<b>City Tier</b>",
    legend_title='<b>City Tier</b>',
    legend_title_font_color="#83502e",
                  plot_bgcolor ='#fdf1cb'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e0eb2692-7b71-4d16-8f64-41a7a6f8ac28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0eb2692-7b71-4d16-8f64-41a7a6f8ac28")) {                    Plotly.newPlot(                        "e0eb2692-7b71-4d16-8f64-41a7a6f8ac28",                        [{"alignmentgroup":"True","hovertemplate":"City Tier=%{y}\u003cbr\u003eTrans_Per_City=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-1","marker":{"color":"#83502e","pattern":{"shape":""}},"name":"Tier-1","offsetgroup":"Tier-1","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x:True}","x":[1943],"xaxis":"x","y":["Tier-1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City Tier=%{y}\u003cbr\u003eTrans_Per_City=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-2","marker":{"color":"#bd7e4a","pattern":{"shape":""}},"name":"Tier-2","offsetgroup":"Tier-2","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x:True}","x":[41],"xaxis":"x","y":["Tier-2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City Tier=%{y}\u003cbr\u003eTrans_Per_City=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-3","marker":{"color":"#d2a56d","pattern":{"shape":""}},"name":"Tier-3","offsetgroup":"Tier-3","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x:True}","x":[9],"xaxis":"x","y":["Tier-3"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observation: </b>From the Horizontal Bar plot we can see very high number transactions per city in Tier-1 (<b>1943</b> Transactions), followed by Tier-2 (<b>41</b> Transactions) and Tier-3 (<b>9</b> Transactions). This is evident that there is lot scope for business expansion in Tier-2 and Tier-3 cities.

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Transaction Count Analysis by Credit Card Type Across City Tiers</div>

# %%
tier_cdd_df = ccd_df[['City Tier','Card Type']].groupby(['City Tier','Card Type']).size().reset_index()

tier_cdd_df.columns = ['City Tier',	'Card Type','Count']

tier_cdd_df = ccd_df[['City Tier','Card Type']].groupby(['City Tier','Card Type']).size().reset_index()

tier_cdd_df.columns = ['City Tier',	'Card Type','Count']

fig1=px.bar(data_frame=tier_cdd_df, x='City Tier', y='Count', color='Card Type', barmode='group', color_discrete_sequence=colors, text_auto='True')

fig1.update_layout(
    title='<b>Transaction count across Cities Tiers</b>',
    font_family="Times New Roman",
    title_font_family="Times New Roman",
    title_font_color="#83502e",
    title_font_size=20,
    xaxis_title="<b>City Tier</b>",
    yaxis_title="<b>Count</b>",
    legend_title='<b>Card Type</b>',
    legend_title_font_color="#83502e",
    plot_bgcolor ='#fdf1cb'
)


fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c6e4475c-8cff-4b9a-a354-3836ba0b3d06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6e4475c-8cff-4b9a-a354-3836ba0b3d06")) {                    Plotly.newPlot(                        "c6e4475c-8cff-4b9a-a354-3836ba0b3d06",                        [{"alignmentgroup":"True","hovertemplate":"Card Type=Gold\u003cbr\u003eCity Tier=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gold","marker":{"color":"#83502e","pattern":{"shape":""}},"name":"Gold","offsetgroup":"Gold","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1","Tier-2","Tier-3"],"xaxis":"x","y":[3288,897,2182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Card Type=Platinum\u003cbr\u003eCity Tier=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Platinum","marker":{"color":"#bd7e4a","pattern":{"shape":""}},"name":"Platinum","offsetgroup":"Platinum","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1","Tier-2","Tier-3"],"xaxis":"x","y":[3330,847,2221],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Card Type=Signature\u003cbr\u003eCity Tier=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Signature","marker":{"color":"#d2a56d","pattern":{"shape":""}},"name":"Signature","offsetgroup":"Signature","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1","Tier-2","Tier-3"],"xaxis":"x","y":[3342,905,2200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Card Type=Silver\u003cbr\u003eCity Tier=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Silver","marker":{"color":"#f1c27d","pattern":{"shape":""}},"name":"Silver","offsetgroup":"Silver","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1","Tier-2","Tier-3"],"xaxis":"x","y":[3643,884,2313],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"cont ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.0;"> <b>Observation: </b>The number of transactions are nearly same across all Card types and City Tiers, with little higher count on Silver cards.

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Transaction Amount Analysis by Credit Card Type Across City Tiers</div>

# %%
tier_ccd_amt_df = ccd_df[['City Tier','Card Type', 'Amount']].groupby(['City Tier','Card Type']).sum('Amount').reset_index()
tier_ccd_amt_df.columns = ['City Tier','Card Type','Amount']

fig=px.bar(data_frame=tier_ccd_amt_df, x='City Tier', y='Amount', color='Card Type', barmode='group', color_discrete_sequence=colors, text_auto='True')

fig.update_layout(
    title='<b>Transaction Amount Analysis by Credit Card Type Across City Tiers </b>',
    font_family="Courier New",
    title_font_family="Courier New",
    title_font_color="#83502e",
    title_font_size=20,
    xaxis_title="<b>City Tier</b>",
    yaxis_title="<b>Count</b>",
    legend_title='<b>Card Type</b>',
    legend_title_font_color='#fdf1cb',
    plot_bgcolor = '#fdf1cb'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="566ed823-dfd4-4707-a662-c8ae6da851ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("566ed823-dfd4-4707-a662-c8ae6da851ae")) {                    Plotly.newPlot(                        "566ed823-dfd4-4707-a662-c8ae6da851ae",                        [{"alignmentgroup":"True","hovertemplate":"Card Type=Gold\u003cbr\u003eCity Tier=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gold","marker":{"color":"#83502e","pattern":{"shape":""}},"name":"Gold","offsetgroup":"Gold","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1","Tier-2","Tier-3"],"xaxis":"x","y":[514508435,132594833,337436268],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Card Type=Platinum\u003cbr\u003eCity Tier=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Platinum","marker":{"color":"#bd7e4a","pattern":{"shape":""}},"name":"Platinum","offsetgroup":"Platinum","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1","Tier-2","Tier-3"],"xaxis":"x","y":[528143971,128458473,351036575],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Card Type=Signature\u003cbr\u003eCity Tier=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Signature","marker":{"color":"#d2a56d","pattern":{"shape":""}},"name":"Signature","offsetgroup":"Signature","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1","Tier-2","Tier-3"],"xaxis":"x","y":[528455161,138345529,346240415],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Card Type=Silver\u003cbr\u003eCity Tier=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Silver","marker":{"color":"#f1c27d","pattern":{"shape":""}},"name":"Silver","offsetgroup":"Silver","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:True}","x":["Tier-1","Tier-2","Tier-3"],"xaxis":"x","y":[579947644,133807690,355858379],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888 ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observation: </b>The pattern of amount on cards is similarly to the pattern seen in transactions count. Total transaction amounts remain consistent across all card types and city tiers, with slightly higher counts observed on Silver cards.

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Analysis of Male and Female Spend Patterns</div>

# %%
def exp_plot(gender):
  exp_df = ccd_df[ccd_df['Gender']==gender][['City Tier', 'Exp Type', 'Amount']]
  exp_df = exp_df.sort_values(['City Tier'])
  if gender=='M':
    gender_name='Male'
  else:
    gender_name='Female'

  fig=px.violin(data_frame=exp_df,
                x=['City Tier','Exp Type'],y='Amount',template='simple_white',
                color = 'Exp Type',box=True,
                category_orders={"Exp Type"  : ['Bills', 'Food', 'Entertainment',
                                                'Grocery', 'Fuel', 'Travel'],
                                 "City Tier" : ['Tier-1', 'Tier-2', 'Tier-3']},
                color_discrete_sequence=colors2)
  fig.update_yaxes(showgrid=True)

  fig.update_layout(
      title='<b>%s - Spend Pattern</b>' %gender_name,
      font_family="Courier New",
      title_font_family="Courier New",
      title_font_color="red",
      title_font_size=20,
      xaxis_title="<b>Year Month</b>",
      yaxis_title="<b>Mean Expenditure</b>",
      legend_title='<b>Exp Type</b>',
      legend_title_font_color="red",
      plot_bgcolor = '#FFFFFF'
  )

  fig.show()

# %%
exp_plot('F')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7de0b07f-6e4c-4c70-90c0-8edb1dfb5c80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7de0b07f-6e4c-4c70-90c0-8edb1dfb5c80")) {                    Plotly.newPlot(                        "7de0b07f-6e4c-4c70-90c0-8edb1dfb5c80",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Exp Type=Bills\u003cbr\u003evalue=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bills","marker":{"color":"red"},"name":"Bills","offsetgroup":"Bills","orientation":"v","scalegroup":"True","showlegend":true,"x":["Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1 ...

# %%
exp_plot('M')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e8946e2c-d10a-41d9-a68d-c62fe35237b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8946e2c-d10a-41d9-a68d-c62fe35237b6")) {                    Plotly.newPlot(                        "e8946e2c-d10a-41d9-a68d-c62fe35237b6",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Exp Type=Bills\u003cbr\u003evalue=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bills","marker":{"color":"red"},"name":"Bills","offsetgroup":"Bills","orientation":"v","scalegroup":"True","showlegend":true,"x":["Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1","Tier-1 ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observation: </b>All of the Expenses Types except <b>'Bills'</b> are having values between <b>1K</b> and <b>300K</b>. The spending pattern is same for both <b>Male</b> and <b>Female</b>.
#     For expense type <b>'Bills'</b> the values are from <b>1K</b> to <b>1M</b>.
#     There are <b>no records</b> for Expense type <b>Travel</b> in Tier-3. This can be a good case for new business expansion in Tier-3 cities

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Analysis of High Value Transactions</div>

# %%
e300k_ccd_df =ccd_df[(ccd_df['Amount'] >= 300000)][['City Tier', 'Card Type', 'Amount']]
fig=px.histogram(e300k_ccd_df, x='Amount' , color='City Tier', nbins=50, text_auto=True, template='ggplot2', color_discrete_sequence=colors)
fig.update_layout(bargap=0)
fig.update_layout(yaxis_range=[0,20])

fig.update_layout(
    title='<b>High Value Transaction Distribution</b>',
    font_family="Times New Roman",
    title_font_family="Times New Roman",
    title_font_color="#83502e",
    title_font_size=20,
    xaxis_title="<b>Amount</b>",
    yaxis_title="<b>Count</b>",
    legend_title='<b>City Tier</b>',
    legend_title_font_color='#fdf1cb',
    plot_bgcolor = '#fdf1cb'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="687a0f15-a8f5-4d58-97c2-1dfaa8fc7df1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("687a0f15-a8f5-4d58-97c2-1dfaa8fc7df1")) {                    Plotly.newPlot(                        "687a0f15-a8f5-4d58-97c2-1dfaa8fc7df1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"City Tier=Tier-3\u003cbr\u003eAmount=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-3","marker":{"color":"#83502e","pattern":{"shape":""}},"name":"Tier-3","nbinsx":50,"offsetgroup":"Tier-3","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[302834,647116,421878,986379,735566,467014,655846,314366,551340,574023,545977,557370,549794,358185,991685,533762,829742,835872,525977,789393,689478,998077,561220,762534,664632,858729,646426,944398,919997,535101,978301,880406,605615,488136,567623,555123,752610,494540,990700,559262,554281,496047,929247,681749,877569,570791,806821,515472,333483,927864,365724,738108,887442,738456,334116,855465,978989,489540,811899,677645,326162,734396,790800,638570,380409,601631,936294,834691,424370,768467,912334,511168,464656,307563,668736,608427,489043,731261,825475,922630,922206,389097,327971,994184,654519],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"City Tier=Tier-1\u003cbr\u003eAmount=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tier-1","marker":{"color":"#bd7e4a","pattern":{"shape":""}},"name":"Tier-1","nbinsx":50,"offsetgroup":"Tier-1","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[366102,809623,668568,339112,622170,434427,987935,702774,864090,440605,954660,337352,660244,401351,678842,478861,804938,888341,892016,313626,735037,402300,733125,371572,326283,900101,545286,722587,411062,660910,340133,441527,550782,540497,499079,665107,934205,823426,418675,804949,686601,327947,492986,369237,983839,776716,466727,896384,712001,581882,687088,973026,414422,408503,984466,447241,382191,775859,832637,458526,440995,490128,897079,431948,757649,919877,500852,937828,315873,498843,996754,974384,846635,635473,478671,809907,428316,845653,440572,478115,897621,365045,466814,835177,784541,576994,464663,380270,772082,677654,851374,637600,847958,450413,866572,705464,352207,342761,995634,435097,797815,326922,396241,486949,612572,327244,955468,555220,952640,695749,650785,611486,965721,413052,584822,980146,926072,482394,718346,491598,848852,396139,856974,855990,924776,780669,687879,378535,772360,580796,451874,670750,977951,403466,861177,528612,339670,963751,761930,852806,566945,705690,894888,316946,622373,640653,745493,868021,814422,599741,804560,996291,477553,722048,400393,981404,639670,814333,569582,954111,635267,393651,572306,407647,830697,690534,423661,537050,899343,593991,781959,553907,308622,586474,521237,446266,608438,973519,688577,686619,407564,331349,391325,530244,517448,788531,474729,590841,719835,375139,376453,360009,770346,503037,752172,418009,994537,880778,689201,792440,602222,502399,613280,876491,820217,515263,338527,934683,454570,958047,465281,653161,307350],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb( ...

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observation: </b>We can see the high value transactions exists in <b>Tier-1</b> and <b>Tier-3</b> cities, but not in <b>Tier-2</b> cities. The high value transactions in Tier-1 are more in number when compared to Tier-3 cities.

# %% [markdown]
# # <div style="text-align: left; background-color: #d2a56d;  color: black; padding: 14px; line-height: 0.5;"> ML Model</div>

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Feature Engineering and Model Building</div>

# %%
ml_ccd_df = ccd_df.copy()

print(Back.YELLOW+ Style.BRIGHT+'Data for Model Building:'+ Style.RESET_ALL)
ml_ccd_df.head().style.set_properties(**{'background-color': '#f1c27d' ,'color':'black','border-color': '#000000'})
# Out:
# Data for Model Building:
# <style type="text/css">
# #T_1c881_row0_col0, #T_1c881_row0_col1, #T_1c881_row0_col2, #T_1c881_row0_col3, #T_1c881_row0_col4, #T_1c881_row0_col5, #T_1c881_row0_col6, #T_1c881_row0_col7, #T_1c881_row0_col8, #T_1c881_row1_col0, #T_1c881_row1_col1, #T_1c881_row1_col2, #T_1c881_row1_col3, #T_1c881_row1_col4, #T_1c881_row1_col5, #T_1c881_row1_col6, #T_1c881_row1_col7, #T_1c881_row1_col8, #T_1c881_row2_col0, #T_1c881_row2_col1, #T_1c881_row2_col2, #T_1c881_row2_col3, #T_1c881_row2_col4, #T_1c881_row2_col5, #T_1c881_row2_col6, #T_1c881_row2_col7, #T_1c881_row2_col8, #T_1c881_row3_col0, #T_1c881_row3_col1, #T_1c881_row3_col2, #T_1c881_row3_col3, #T_1c881_row3_col4, #T_1c881_row3_col5, #T_1c881_row3_col6, #T_1c881_row3_col7, #T_1c881_row3_col8, #T_1c881_row4_col0, #T_1c881_row4_col1, #T_1c881_row4_col2, #T_1c881_row4_col3, #T_1c881_row4_col4, #T_1c881_row4_col5, #T_1c881_row4_col6, #T_1c881_row4_col7, #T_1c881_row4_col8 {
#   background-color: #f1c27d;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_1c881" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c881_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_1c881_level0_col1" class="col_heading level0 col1" >City</th>
#       <th id="T_1c881_level0_col2" class="col_heading level0 col2" >Date</th>
#       <th id="T_1c881_level0_col3" class="col_heading level0 col3" >Card Type</th>
#       <th id="T_1c881_level0_col4" class="col_heading level0 col4" >Exp Type</th>
#       <th id="T_1c881_level0_col5" class="col_heading level0 col5" >Gender</th>
#       <th id="T_1c881_level0_col6" class="col_heading level0 col6" >Amount</th>
#       <th id="T_1c881_level0_col7" class="col_heading level0 col7" >Year-Month</th>
#       <th id="T_1c881_level0_col8" class="col_heading level0 col8" >City Tier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c881_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c881_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1c881_row0_col1" class="data row0 col1" >Delhi</td>
#       <td id="T_1c881_row0_col2" class="data row0 col2" >2014-10-29 00:00:00</td>
#       <td id="T_1c881_row0_col3" class="data row0 col3" >Gold</td>
#       <td id="T_1c881_row0_col4" class="data row0 col4" >Bills</td>
#       <td id="T_1c881_row0_col5" class="data row0 col5" >F</td>
#       <td id="T_1c881_row0_col6" class="data row0 col6" >82475</td>
#       <td id="T_1c881_row0_col7" class="data row0 col7" >2014-10-01 00:00:00</td>
#       <td id="T_1c881_row0_col8" class="data row0 col8" >Tier-1</td>
#     </tr>
#     <tr>
#       <th id="T_1c881_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1c881_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_1c881_row1_col1" class="data row1 col1" >Greater Mumbai</td>
#       <td id="T_1c881_row1_col2" class="data row1 col2" >2014-08-22 00:00:00</td>
#       <td id="T_1c881_row1_col3" class="data row1 col3" >Platinum</td>
#       <td id="T_1c881_row1_col4" class="data row1 col4" >Bills</td>
#       <td id="T_1c881_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_1c881_row1_col6" class="data row1 col6" >32555</td>
#       <td id="T_1c881_row1_col7" class="data row1 col7" >2014-08-01 00:00:00</td>
#       <td id="T_1c881_row1_col8" class="data row1 col8" >Tier-3</td>
#     </tr>
#     <tr>
#       <th id="T_1c881_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1c881_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_1c881_row2_col1" class="data row2 col1" >Bengaluru</td>
#       <td id="T_1c881_row2_col2" class="data row2 col2" >2014-08-27 00:00:00</td>
#       <td id="T_1c881_row2_col3" class="data row2 col3" >Silver</td>
#       <td id="T_1c881_row2_col4" class="data row2 col4" >Bills</td>
#       <td id="T_1c881_row2_col5" class="data row2 col5" >F</td>
#       <td id="T_1c881_row2_col6" class="data row2 col6" >101738</td>
#       <td id="T_1c881_row2_col7" class="data row2 col7" >2014-08-01 00:00:00</td>
#       <td id="T_1c881_row2_col8" class="data row2 col8" >Tier-1</td>
#     </tr>
#     <tr>
#       <th id="T_1c881_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1c881_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_1c881_row3_col1" class="data row3 col1" >Greater Mumbai</td>
#       <td id="T_1c881_row3_col2" class="data row3 col2" >2014-04-12 00:00:00</td>
#       <td id="T_1c881_row3_col3" class="data row3 col3" >Signature</td>
#       <td id="T_1c881_row3_col4" class="data row3 col4" >Bills</td>
#       <td id="T_1c881_row3_col5" class="data row3 col5" >F</td>
#       <td id="T_1c881_row3_col6" class="data row3 col6" >123424</td>
#       <td id="T_1c881_row3_col7" class="data row3 col7" >2014-04-01 00:00:00</td>
#       <td id="T_1c881_row3_col8" class="data row3 col8" >Tier-3</td>
#     </tr>
#     <tr>
#       <th id="T_1c881_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1c881_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_1c881_row4_col1" class="data row4 col1" >Bengaluru</td>
#       <td id="T_1c881_row4_col2" class="data row4 col2" >2015-05-05 00:00:00</td>
#       <td id="T_1c881_row4_col3" class="data row4 col3" >Gold</td>
#       <td id="T_1c881_row4_col4" class="data row4 col4" >Bills</td>
#       <td id="T_1c881_row4_col5" class="data row4 col5" >F</td>
#       <td id="T_1c881_row4_col6" class="data row4 col6" >171574</td>
#       <td id="T_1c881_row4_col7" class="data row4 col7" >2015-05-01 00:00:00</td>
#       <td id="T_1c881_row4_col8" class="data row4 col8" >Tier-1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Data Transformation</div>

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Transformation: </b>To convert the <b>Gender</b> categorical feature to numeric feature we shall map values <b>F</b> to <b>0</b> and <b>M</b> to <b>1</b>.
#
# To convert the <b>City Tier</b> categorical feature to numeric feature we shall map values <b>Tier-1</b> to <b>1</b>, <b>Tier-2</b> to <b>2</b>, <b>Tier-3</b> to <b>3</b>
#
# To convert the categorical features <b>Exp Type</b> and <b>Card Type</b> to numeric features we shall use <b>LabelEncoder()</b>

# %%
ml_ccd_df['Gender'] = ml_ccd_df['Gender'].map({'F':0, 'M':1})

ml_ccd_df['City Tier'] = ml_ccd_df['City Tier'].map({'Tier-1':1, 'Tier-2':2, 'Tier-3':3})

from sklearn import preprocessing


label_encoder = preprocessing.LabelEncoder()

# Encode labels
ml_ccd_df['Exp Type']= label_encoder.fit_transform(ml_ccd_df['Exp Type'])
ml_ccd_df['Card Type']= label_encoder.fit_transform(ml_ccd_df['Card Type'])

ml_ccd_df.drop(['index', 'City', 'Date', 'Year-Month'], axis=1, inplace=True)

print(Back.YELLOW+ Style.BRIGHT+'Data for Model Building:'+ Style.RESET_ALL)
ml_ccd_df.head().style.set_properties(**{'background-color': '#f1c27d' ,'color':'black','border-color': '#000000'})
# Out:
# Data for Model Building:
# <style type="text/css">
# #T_7bee0_row0_col0, #T_7bee0_row0_col1, #T_7bee0_row0_col2, #T_7bee0_row0_col3, #T_7bee0_row0_col4, #T_7bee0_row1_col0, #T_7bee0_row1_col1, #T_7bee0_row1_col2, #T_7bee0_row1_col3, #T_7bee0_row1_col4, #T_7bee0_row2_col0, #T_7bee0_row2_col1, #T_7bee0_row2_col2, #T_7bee0_row2_col3, #T_7bee0_row2_col4, #T_7bee0_row3_col0, #T_7bee0_row3_col1, #T_7bee0_row3_col2, #T_7bee0_row3_col3, #T_7bee0_row3_col4, #T_7bee0_row4_col0, #T_7bee0_row4_col1, #T_7bee0_row4_col2, #T_7bee0_row4_col3, #T_7bee0_row4_col4 {
#   background-color: #f1c27d;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_7bee0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bee0_level0_col0" class="col_heading level0 col0" >Card Type</th>
#       <th id="T_7bee0_level0_col1" class="col_heading level0 col1" >Exp Type</th>
#       <th id="T_7bee0_level0_col2" class="col_heading level0 col2" >Gender</th>
#       <th id="T_7bee0_level0_col3" class="col_heading level0 col3" >Amount</th>
#       <th id="T_7bee0_level0_col4" class="col_heading level0 col4" >City Tier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bee0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7bee0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7bee0_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7bee0_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7bee0_row0_col3" class="data row0 col3" >82475</td>
#       <td id="T_7bee0_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bee0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7bee0_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_7bee0_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_7bee0_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_7bee0_row1_col3" class="data row1 col3" >32555</td>
#       <td id="T_7bee0_row1_col4" class="data row1 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7bee0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7bee0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7bee0_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_7bee0_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_7bee0_row2_col3" class="data row2 col3" >101738</td>
#       <td id="T_7bee0_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7bee0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7bee0_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_7bee0_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_7bee0_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_7bee0_row3_col3" class="data row3 col3" >123424</td>
#       <td id="T_7bee0_row3_col4" class="data row3 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7bee0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7bee0_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_7bee0_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_7bee0_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_7bee0_row4_col3" class="data row4 col3" >171574</td>
#       <td id="T_7bee0_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(18, 6))
sns.heatmap(ml_ccd_df.corr(),
            cmap = 'BrBG',
            fmt = '.2f',
            linewidths = 2,
            annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Splitting Data into Train and Test</div>

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Split: </b>To split the data we shall use <b>sklearn.model_selection.train_test_split</b>.
#
# <b>Standardize: </b>To Standardize, we shall use <b>StandardScaler</b>

# %%
X= ml_ccd_df[[ 'Card Type', 'Exp Type', 'Gender', 'City Tier']]
y= ml_ccd_df[['Amount']]


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=25)

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Linear Regression Model</div>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
y_pred = lm.predict(X_test)
r2_scoree = r2_score(y_test, y_pred)
print(Back.YELLOW+ Style.BRIGHT+'R Squared Score for Linear Regression Model is:'+ str(r2_scoree) + Style.RESET_ALL)
# Out:
# R Squared Score for Linear Regression Model is:0.004282175865952698

# %% [markdown]
# ### <div style="text-align: left; background-color: #E0B279;  color: black; padding: 14px; line-height: 0.5;"> Random Forest Model</div>

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=10)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
r2_scoree = r2_score(y_test, y_pred)
print(Back.YELLOW+ Style.BRIGHT+'R Squared Score for Random Forest Regression Model is:'+ str(r2_scoree) + Style.RESET_ALL)
# Out:
# R Squared Score for Random Forest Regression Model is:0.012703289432566711

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Observation: </b>The Random Forest Model appears to be better than Linear Regression Model, but these models need further tuning.

# %% [markdown]
# <div style="text-align: left; background-color: #fdf1cb;  color: black; padding: 14px; line-height: 1.25;"> <b>Further Observations on Dataset : </b> There is no specific trend observed in monthly transaction count. The sum of transaction amounts is nearly same in all of the cards types with little upper side on one of the card types.
#
# Female spends are more than Male and has high values transactions (amount greater than 300K) under Expenses Type Bills. In general the Bills paid on credit cards cannot be as high as 900K.
#
# In view of these observations, we can say that the data provided in the dataset is a summarised data and not of individual transactions.
#
# The Data provided in the dataset helps in identifying venues for Credit Card business expansion.
